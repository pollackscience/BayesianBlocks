# %% [markdown]
# # Plots for Binning comparison, and Metrics

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function
import os
import six.moves.cPickle as pkl
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import gridspec
from matplotlib.ticker import MaxNLocator, ScalarFormatter
#from bb.tools.hist_tools_modified import hist, poisson_error
from skhep.visual import MplPlotter as skh_plt
from skhep.modeling import bayesian_blocks
from astropy.stats import knuth_bin_width
from utilities import rough, err_nn, err_li
from vis_comp import comp_study
from scipy import special
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
from tqdm import tnrange, tqdm_notebook

# %%
bb_dir = os.path.join('/Users/brianpollack/Coding/BayesianBlocks')
dy_data = pd.read_pickle(bb_dir+'/files/DY/ZLL_v2.p')
z_data = dy_data.query('50<Mll<140').Mll.values
mu_data = dy_data.query('0<Muon1_Pt').Muon1_Pt.values
pt_data = pd.read_pickle(bb_dir+'/files/DY/ZLL_Jet_all.p')
pt_data = pt_data.query('0<leading_jet_pT<800').reset_index().leading_jet_pT.values
dist_dict = {'DY':z_data, 'MuPT':mu_data, 'jPT':pt_data}
# dist_dict = {'jPT':pt_data}

# %%
#for dist_name in tqdm_notebook(dist_dict, desc='Dist'):
for n_events in tqdm_notebook([500,1000,5000,10000,50000], desc='n_events', leave=False):
# for n_events in tqdm_notebook([10000,], desc='n_events', leave=False):
    comp_study(dist_dict['DY'], n_events, xlims=False, dist_name='DY')
# Out:
# HBox(children=(IntProgress(value=0, description='n_events', max=1), HTML(value='')))
# [ 56.38703557  61.41831497  66.44959437  71.48087377  76.51215318
#   81.54343258  86.57471198  91.60599138  96.63727079 101.66855019
#  106.69982959 111.73110899 116.7623884  121.7936678  126.8249472 ]
# [   4.37264525    5.76394147    9.93783012   14.31047538   30.40976017
#    98.78203141  451.17748754 1047.64605147  249.63829267   41.34137331
#    17.09306781    7.15523769    4.37264525    4.37264525    1.19253961]
# [ 59.42309506  70.16843873  77.90961002  81.06455474  82.80145691
#   84.61764261  86.26526954  87.8200299   89.08472052  91.06456562
#   92.88128617  94.16618148  95.32364693  96.69522113  98.82392027
#  102.54949206 111.05914918 123.16062384]
# [   4.95343841   13.76682603   37.68360737   81.49249192  136.78809633
#   214.79494537  368.39484964  603.70317401  884.69095195 1223.46295724
#   941.44305907  600.90266983  373.38813298  197.72557595   92.7532653
#    34.00117922    9.11929313    2.50810561]

# %%
for n_events in tqdm_notebook([500,1000,5000,10000,50000], desc='n_events', leave=False):
# for n_events in tqdm_notebook([10000,], desc='n_events', leave=False):
    comp_study(dist_dict['MuPT'], n_events, xlims=False, dist_name='MuPT')
# Out:
# HBox(children=(IntProgress(value=0, description='n_events', max=1), HTML(value='')))
# [ 23.48681657  30.07107108  36.65532558  43.23958009  49.82383459
#   56.40808909  62.9923436   69.5765981   76.1608526   82.74510711
#   89.32936161  95.91361611 102.49787062 109.08212512 115.66637962]
# [4.07031654e+01 1.35474715e+02 2.67608125e+02 4.82211008e+02
#  3.77871177e+02 1.26210188e+02 4.82970395e+01 2.24778675e+01
#  9.11264897e+00 4.40444700e+00 2.12628476e+00 1.36689735e+00
#  4.55632448e-01 3.03754966e-01 1.51877483e-01]
# [ 21.01907683  23.20416441  26.3285252   29.70312527  33.93563148
#   39.06461811  42.53494493  45.82782392  49.07374974  51.14309752
#   54.14599518  58.1925051   63.40148053  71.03549567  80.3556279
#   90.68795892 107.64035522]
# [1.03106851e+01 3.93179958e+01 7.39938240e+01 1.26323811e+02
#  1.98736111e+02 3.33011650e+02 4.45006616e+02 5.74255839e+02
#  4.00675199e+02 2.86979149e+02 1.67882870e+02 9.58122032e+01
#  4.41571569e+01 1.91473652e+01 5.53416815e+00 2.04108993e+00
#  3.09237772e-01]

# %%
#for n_events in tqdm_notebook([500,1000,5000,10000,20000,30000], desc='n_events', leave=False):
for n_events in tqdm_notebook([10000,], desc='n_events', leave=False):
    comp_study(dist_dict['jPT'], n_events, xlims=False, dist_name='jPT')
# Out:
# HBox(children=(IntProgress(value=0, description='n_events', max=1), HTML(value='')))
# [ 48.91172918  96.73315811 144.55458705 192.37601598 240.19744492
#  288.01887385 335.84030279 383.66173172 431.48316065 479.30458959
#  527.12601852 574.94744746 622.76887639 670.59030533 718.41173426]
# [1.66055264e+02 2.96728900e+01 8.00896185e+00 3.15758026e+00
#  1.06646750e+00 4.18222551e-01 4.18222551e-01 1.67289020e-01
#  8.36445102e-02 2.09111275e-02 0.00000000e+00 0.00000000e+00
#  2.09111275e-02 0.00000000e+00 2.09111275e-02]
# [ 27.22247171  31.41404295  35.27628136  41.13529682  49.27050591
#   58.32073498  68.61238766  79.65865707  89.31259155 101.92477036
#  119.88186836 142.59613037 178.58592224 238.4607811  332.40795135
#  565.72028351]
# [3.76329588e+02 3.04297076e+02 2.47076807e+02 1.84023193e+02
#  1.30748188e+02 9.51471613e+01 6.73784517e+01 4.65712224e+01
#  3.43505197e+01 2.30954343e+01 1.50603605e+01 7.26486388e+00
#  3.95355469e+00 1.18162033e+00 3.26220165e-01 2.26497789e-02]

# %%
# for n_events in tqdm_notebook([500,1000,5000,10000,20000,30000], desc='n_events', leave=False):
for n_events in tqdm_notebook([10000,], desc='n_events', leave=False):
    comp_study(None, n_events, xlims=False, dist_name='2Gauss')
# Out:
# HBox(children=(IntProgress(value=0, description='n_events', max=1), HTML(value='')))
# [ 93.7490383   95.06270186  96.37636541  97.69002896  99.00369251
#  100.31735606 101.63101961 102.94468316 104.25834671 105.57201026
#  106.88567381 108.19933736 109.51300091 110.82666446 112.14032801]
# [   9.13475905   62.42085348  277.84892099  666.07618047 1143.36734064
#  1309.31546332 1050.49729034  518.39757588  226.0852864   140.06630538
#   119.51309752  247.39972417 1009.39087463  771.1259095    61.65962356]
# [ 93.69346676  94.54795399  95.28618737  95.9712415   96.55308746
#   97.40289218  98.32377621 100.01897519 101.66363933 102.26246752
#  102.79113313 103.4680749  104.40288473 106.63905733 108.55760898
#  109.12543049 110.03576829 110.8544604  111.32562736 111.86018998
#  112.46224702]
# [   8.31586677   33.56672182   74.22582612  177.45764053  314.30214592
#   538.45406279  888.76124439 1289.52132828 1036.42991309  791.40699513
#   552.411164    372.72125218  203.37322739  126.66114201  379.91798645
#   770.15705294 1178.15701258  780.37340682  314.1145764    89.83909538
#     8.95755649]
